# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# conhecendo o dataset

# %%
df = pd.read_csv('database.csv', index_col='id')

# %%
df.head() #pega os 5 primeiros
# Out:
#     age          job   marital            education default housing loan  \
# id
# 0    52   technician  divorced  professional.course     NaN     yes   no
# 1    36   management   married    university.degree      no     yes   no
# 2    53  blue-collar   married          high.school      no     yes  yes
# 3    45  blue-collar    single             basic.9y      no     yes   no
# 4    60    housemaid   married          high.school     NaN     yes   no
#
#       contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# id                               ...
# 0   telephone   jun         mon  ...         8    999         0  nonexistent
# 1    cellular   nov         tue  ...         2    999         0  nonexistent
# 2    cellular   jul         mon  ...         2    999         0  nonexistent
# 3    cellular   aug         wed  ...         1      4         1      success
# 4   telephone   may         wed  ...         1    999         0  nonexistent
#
# ...

# %%
df.head(10) #os 10 primeiros
# Out:
#     age          job   marital  ... euribor3m nr.employed   y
# id                              ...
# 0    52   technician  divorced  ...     4.865      5228.1  no
# 1    36   management   married  ...     4.153      5195.8  no
# 2    53  blue-collar   married  ...     4.962      5228.1  no
# 3    45  blue-collar    single  ...     0.879      5076.2  no
# 4    60    housemaid   married  ...     4.858      5191.0  no
# 5    57      retired   married  ...     1.405      5099.1  no
# 6    48   technician    single  ...     1.334      5099.1  no
# 7    45  blue-collar   married  ...     4.864      5228.1  no
# 8    30  blue-collar    single  ...     4.858      5191.0  no
# 9    34  blue-collar   married  ...     1.313      5099.1  no
#
# [10 rows x 21 columns]

# %%
df #5 primeiros e 5 últimos
# Out:
#        age          job   marital  ... euribor3m nr.employed   y
# id                                 ...
# 0       52   technician  divorced  ...     4.865      5228.1  no
# 1       36   management   married  ...     4.153      5195.8  no
# 2       53  blue-collar   married  ...     4.962      5228.1  no
# 3       45  blue-collar    single  ...     0.879      5076.2  no
# 4       60    housemaid   married  ...     4.858      5191.0  no
# ...    ...          ...       ...  ...       ...         ...  ..
# 37064   28     services    single  ...     0.876      4991.6  no
# 37065   52   technician   married  ...     4.021      5195.8  no
# 37066   54       admin.   married  ...     4.962      5228.1  no
# 37067   29       admin.   married  ...     4.864      5191.0  no
# 37068   35       admin.   married  ...     4.961      5228.1  no
#
# [37069 rows x 21 columns]

# %%
df.tail(5) #pega uma quantidade determinada de baixo pra cima
# Out:
#        age         job  marital  ... euribor3m nr.employed   y
# id                               ...
# 37064   28    services   single  ...     0.876      4991.6  no
# 37065   52  technician  married  ...     4.021      5195.8  no
# 37066   54      admin.  married  ...     4.962      5228.1  no
# 37067   29      admin.  married  ...     4.864      5191.0  no
# 37068   35      admin.  married  ...     4.961      5228.1  no
#
# [5 rows x 21 columns]

# %%
df.sample(5) #sorteia uma quantidade de números
# Out:
#        age            job   marital  ... euribor3m nr.employed   y
# id                                   ...
# 28692   43  self-employed    single  ...     4.859      5191.0  no
# 21349   88        retired   married  ...     0.843      5076.2  no
# 30165   28       services   married  ...     4.957      5228.1  no
# 33167   37       services   married  ...     4.866      5228.1  no
# 1440    36    blue-collar  divorced  ...     4.959      5228.1  no
#
# [5 rows x 21 columns]

# %%
df.info() # informações resumidas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37069 entries, 0 to 37068
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             37069 non-null  int64
#  1   job             36773 non-null  object
#  2   marital         37000 non-null  object
#  3   education       35505 non-null  object
#  4   default         29296 non-null  object
#  5   housing         36176 non-null  object
#  6   loan            36176 non-null  object
#  7   contact         37069 non-null  object
#  8   month           37069 non-null  object
#  9   day_of_week     37069 non-null  object
#  10  duration        37069 non-null  int64
#  11  campaign        37069 non-null  int64
#  12  pdays           37069 non-null  int64
#  13  previous        37069 non-null  int64
#  14  poutcome        37069 non-null  object
#  15  emp.var.rate    37069 non-null  float64
#  16  cons.price.idx  37069 non-null  float64
# ...

# %%
df.describe() #mais informações (mean é média, std é desvio padrão), apenas numeros
# Out:
#                 age      duration  ...     euribor3m   nr.employed
# count  37069.000000  37069.000000  ...  37069.000000  37069.000000
# mean      40.023497    258.185492  ...      3.620484   5166.966047
# std       10.412653    259.579105  ...      1.735310     72.360902
# min       17.000000      0.000000  ...      0.634000   4963.600000
# 25%       32.000000    103.000000  ...      1.344000   5099.100000
# 50%       38.000000    180.000000  ...      4.857000   5191.000000
# 75%       47.000000    319.000000  ...      4.961000   5228.100000
# max       98.000000   4918.000000  ...      5.045000   5228.100000
#
# [8 rows x 10 columns]

# %%
df.describe(include='object') # não numeros (categóricos) (unique é a quantidade de categorias,)
# Out:
#            job  marital          education  ... day_of_week     poutcome      y
# count    36773    37000              35505  ...       37069        37069  37069
# unique      11        3                  7  ...           5            3      2
# top     admin.  married  university.degree  ...         thu  nonexistent     no
# freq      9364    22424              10967  ...        7735        31989  32893
#
# [4 rows x 11 columns]

# %%
#problema de regressão - numérica/contínua
#problema de classificação - simples (só uma resposta) ou multipla (mais de uma categoria (genero musical, filme))
plt.figure(figsize=(20,6)) #tamanho
sns.countplot(data=df, x='age', hue= 'y', palette='bright') #conta as frequencias
plt.ylabel('Número de pessoas') # renomear o eixo 
plt.show()

# %%
# A distribuição nao representa a realidade, pois em nenhum país a maioria das pessoas tem diploma, os dados podem estar enviesados

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df, x='job', y='age', hue='y')
plt.show()

# %%
sns.catplot(data=df, x='marital', y='age', hue='y', jitter=0.09) #quanto maior o jitter, maior o espaço

# %%
sns.catplot(data=df, x='y', y='duration', hue='y', jitter=0.09)

# %%
sns.catplot(data=df, x='marital', y='age', hue='y', kind='box')

# %%
plt.figure(figsize=(15, 5))
sns.scatterplot(x='age', y='duration', data=df, hue='y')
plt.show()

# %%
df[df.duration <= 10].count() #quantidade de pessoas cuja duração durou menos que 10 segundos
# Out:
# age               320
# job               318
# marital           319
# education         306
# default           259
# housing           314
# loan              314
# contact           320
# month             320
# day_of_week       320
# duration          320
# campaign          320
# pdays             320
# previous          320
# poutcome          320
# emp.var.rate      320
# cons.price.idx    320
# cons.conf.idx     320
# euribor3m         320
# nr.employed       320
# y                 320
# dtype: int64

# %%
df[df.y == 'yes'].describe()
# Out:
#                age     duration  ...    euribor3m  nr.employed
# count  4176.000000  4176.000000  ...  4176.000000  4176.000000
# mean     40.902299   551.579502  ...     2.131688  5095.297031
# std      13.831597   400.507671  ...     1.745427    87.923517
# min      17.000000    63.000000  ...     0.634000  4963.600000
# 25%      31.000000   252.750000  ...     0.853250  5017.500000
# 50%      37.000000   449.000000  ...     1.266000  5099.100000
# 75%      50.000000   741.250000  ...     4.503500  5191.000000
# max      98.000000  4199.000000  ...     5.045000  5228.100000
#
# [8 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib
from sklearn import metrics
#!pip install joblib

# %%
#Transforma os objetos em categorias
for c in df.columns[df.dtypes == object]: # df.dtypes == 'object'
    df[c] = df[c].astype('category')

# %%
df.job
# Out:
# id
# 0         technician
# 1         management
# 2        blue-collar
# 3        blue-collar
# 4          housemaid
#             ...
# 37064       services
# 37065     technician
# 37066         admin.
# 37067         admin.
# 37068         admin.
# Name: job, Length: 37069, dtype: category
# Categories (11, object): ['admin.', 'blue-collar', 'entrepreneur', 'housemaid', ..., 'services',
#                           'student', 'technician', 'unemployed']

# %%
sum(df.job.isna())#tem 296 dados faltantes (isna é not a number, isnull conta string vazia)
# Out:
# 296

# %%
df.job.cat.codes
# Out:
# id
# 0        9
# 1        4
# 2        1
# 3        1
# 4        3
#         ..
# 37064    7
# 37065    9
# 37066    0
# 37067    0
# 37068    0
# Length: 37069, dtype: int8

# %%
df.job.cat.categories
# Out:
# Index(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed'],
#       dtype='object')

# %%
df.education.cat.categories
# Out:
# Index(['basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'illiterate',
#        'professional.course', 'university.degree'],
#       dtype='object')

# %%
df.education.cat.reorder_categories(['illiterate', 'basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'professional.course', 'university.degree'], ordered=True, inplace=True)

# %%
#transforma categorias em numeros
for c in df.columns[df.dtypes == 'category'] :
    df[c] = df[c].cat.codes

# %%
df.head()
# Out:
#     age  job  marital  education  ...  cons.conf.idx  euribor3m  nr.employed  y
# id                                ...
# 0    52    9        0          5  ...          -41.8      4.865       5228.1  0
# 1    36    4        1          6  ...          -42.0      4.153       5195.8  0
# 2    53    1        1          4  ...          -42.7      4.962       5228.1  0
# 3    45    1        2          3  ...          -31.4      0.879       5076.2  0
# 4    60    3        1          4  ...          -36.4      4.858       5191.0  0
#
# [5 rows x 21 columns]

# %%
#
y = df.y #apenas a coluna alvo
x = df.drop('y', axis=1) # jogando fora a coluna alvo (axis 1 é para falar ao python que é para tirar da coluna)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=42, shuffle=True, stratify=y)
#shuffle embaralha, stratify iguala

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((31508, 20), (5561, 20), (31508,), (5561,))

# %%
#verificando a divisão
sum(y_train)/len(y_train), sum(y_test)/len(y_test)
# Out:
# (0.11266979814650248, 0.11256968171192232)

# %%
#achatar os dados, para todos ficarem no mesmo parametro (normalizar os dados)
scaler = MinMaxScaler()
x_norm = scaler.fit_transform(x)

# %%
df2 = pd.DataFrame(x_norm, columns=df.columns.drop('y'))

# %%
df2.head()
# Out:
#         age       job   marital  ...  cons.conf.idx  euribor3m  nr.employed
# 0  0.432099  0.909091  0.333333  ...       0.376569   0.959193     1.000000
# 1  0.234568  0.454545  0.666667  ...       0.368201   0.797778     0.877883
# 2  0.444444  0.181818  0.666667  ...       0.338912   0.981183     1.000000
# 3  0.345679  0.181818  1.000000  ...       0.811715   0.055543     0.425709
# 4  0.530864  0.363636  0.666667  ...       0.602510   0.957606     0.859735
#
# [5 rows x 20 columns]

# %%
knn_class = KNeighborsClassifier()
